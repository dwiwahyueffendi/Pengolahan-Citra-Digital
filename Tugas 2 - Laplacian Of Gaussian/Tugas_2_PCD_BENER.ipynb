# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-33ea8b38-9c18-4ca7-a95d-306720eb5d6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33ea8b38-9c18-4ca7-a95d-306720eb5d6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving daun1.jpeg to daun1.jpeg

# %%
# memanggil library opencv
import cv2
# memanggil fungsi google colab untuk perbaikan cv2.imshow
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import numpy as np

# menyimpan gambar dengan fungsi imread dari OpenCV
img = cv2.imread("daun1.jpeg")

# %%
# Menerapkan Gaussian filtering gaussiaan
blur = cv2.GaussianBlur(img,(5,5),0)
print('GaussianBlur')
cv2_imshow(blur)
gray = cv2.cvtColor(blur, cv2.COLOR_BGR2GRAY)
print('GreyScale')
cv2_imshow(gray)
# menerapkan algoritma high-pass filtering:
# laplacian
print('laplacian')
laplacian = cv2.Laplacian(gray,cv2.CV_16S,ksize = 3)
# converting back to uint8
log = cv2.convertScaleAbs(laplacian)
cv2_imshow(log)
# Out:
# GaussianBlur
# <PIL.Image.Image image mode=RGB size=1600x1196 at 0x7FC81FE10950>
# GreyScale
# <PIL.Image.Image image mode=L size=1600x1196 at 0x7FC81FD98590>
# laplacian
# <PIL.Image.Image image mode=L size=1600x1196 at 0x7FC81FD98550>

# %%
img_array_grey = np.array(gray)
print ("Array Image Greyscale")
print(img_array_grey)
img_array_laplaciaan = np.array(log)
print ("Array Image Log")
print(img_array_laplaciaan)
# Out:
# Array Image Greyscale
# [[166 166 165 ... 150 149 149]
#  [166 165 165 ... 150 150 149]
#  [165 164 164 ... 150 150 150]
#  ...
#  [151 151 151 ... 133 133 133]
#  [151 151 151 ... 132 132 132]
#  [151 151 151 ... 132 132 132]]
# Array Image Log
# [[8 4 0 ... 0 4 8]
#  [8 0 2 ... 2 2 4]
#  [8 0 4 ... 2 2 0]
#  ...
#  [0 0 2 ... 0 0 0]
#  [0 0 0 ... 4 4 4]
#  [0 0 0 ... 0 0 0]]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(img_array_grey,img_array_laplaciaan)
print(mse)
# Out:
# 113.9854954013378
